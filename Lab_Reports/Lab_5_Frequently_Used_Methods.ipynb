# %% [markdown]
# Lab 4: Frequently Used Methods

# %% [markdown]
# Lab Report Task

# %% [markdown]
#  sum: sum() adds up numbers in a list.
# i.	The power consumed by individual components is listed in a list. Find the total power consumed by adding readings.
# ii.	A list contains the values of a series of connected resistances. Find its equivalent resistance using the sum.
# Example:
# nums = [1, 2, 3]
# print(sum(nums))
# Output:
# 6

# %%
power = [120, 80, 60, 40]
print("Total power consumed:", sum(power))

resistances = [10, 20, 30, 40]
print("Equivalent resistance:", sum(resistances))
# Out:
# Total power consumed: 300
# Equivalent resistance: 100
